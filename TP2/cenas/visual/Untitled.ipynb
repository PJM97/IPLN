# %%
import json
from vega import Vega

# %%
with open('coiso.json') as json_file:
    view = json.load(json_file)

# %%
Vega(view)

# %%
with open('outro.json') as json_file:
    outro = json.load(json_file)

# %%
Vega(outro)

# %%
with open('dab.json') as jf:
    ola = json.load(jf)

# %%
print(ola)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega/v5.json', 'padding': 5, 'width': 720, 'height': 720, 'autosize': 'none', 'signals': [{'name': 'tension', 'value': 0.85, 'bind': {'input': 'range', 'min': 0, 'max': 1, 'step': 0.01}}, {'name': 'radius', 'value': 280, 'bind': {'input': 'range', 'min': 20, 'max': 400}}, {'name': 'extent', 'value': 360, 'bind': {'input': 'range', 'min': 0, 'max': 360, 'step': 1}}, {'name': 'rotate', 'value': 0, 'bind': {'input': 'range', 'min': 0, 'max': 360, 'step': 1}}, {'name': 'textSize', 'value': 8, 'bind': {'input': 'range', 'min': 2, 'max': 20, 'step': 1}}, {'name': 'textOffset', 'value': 2, 'bind': {'input': 'range', 'min': 0, 'max': 10, 'step': 1}}, {'name': 'layout', 'value': 'cluster', 'bind': {'input': 'radio', 'options': ['tidy', 'cluster']}}, {'name': 'colorIn', 'value': 'firebrick'}, {'name': 'colorOut', 'value': 'forestgreen'}, {'name': 'originX', 'update': 'width / 2'}, {'name': 'originY', 'update': 'height / 2'}, {'name': 'active', 'value'
# ...

# %%
Vega(ola)
